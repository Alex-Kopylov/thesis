# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
# !ls -l \data
# Out:
# total 24032
# drwxr-xr-x  4 jupyter jupyter     4096 Apr 16 14:47 asl-alphabet
# drwxr-xr-x 32 jupyter jupyter     4096 Apr 17 18:02 asl-alphabet-test
# drwxr-xr-x  4 jupyter jupyter     4096 Apr 17 18:02 asl-lucas
# drwxr-xr-x  4 jupyter jupyter     4096 Apr 17 18:02 asltestimages
# -rw-r--r--  1 jupyter jupyter 24555365 Apr 18 21:39  data.csv
# -rw-r--r--  1 jupyter jupyter      386 Apr 16 17:28 info_about_datasets.csv
# -rw-r--r--  1 jupyter jupyter      283 Apr 17 18:05 kaggle_datasets.txt
# drwxr-xr-x  4 jupyter jupyter     4096 Apr 16 14:47 significant-asl-sign-language-alphabet-dataset
# drwxr-xr-x  4 jupyter jupyter     4096 Apr 16 14:48 sign-language-gesture-images-dataset
# drwxr-xr-x  2 jupyter jupyter     4096 Apr 16 14:48 sign-language-kernel-data
# drwxr-xr-x  5 jupyter jupyter     4096 Apr 16 14:52 sign-language-mnist
# -rw-r--r--  1 jupyter jupyter     3661 Apr 17 18:02 Untitled1.ipynb
# -rw-r--r--  1 jupyter jupyter     5975 Apr 18 21:48 Untitled.ipynb

# %%
df = pd.read_csv("data/data.csv")

# %%
plt.figure(figsize=(20, 5))
ax = sns.countplot(x="dataset", data=df)

# %%
uppercase = [chr(i) for i in range(ord('A'),ord('Z')+1)]
plt.figure(figsize=(20, 5))
ax = sns.countplot(x="label", data = (df[df.isin({'label': uppercase})]))
